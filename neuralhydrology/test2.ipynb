# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/neuralhydrology')
#!pip install ruamel.yaml

# %%
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import torch
# !pip install -r /content/drive/MyDrive/neuralhydrology/environments/rtd_requirements.txt
# !pip install ruamel.yaml
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.2 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 34.9 MB/s
# ...
#      |████████████████████████████████| 84 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 121 kB 48.6 MB/s
# ...
#      |████████████████████████████████| 100 kB 11.1 MB/s
# ...
#      |████████████████████████████████| 90 kB 6.7 MB/s
# ...
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
start_run(config_file=Path("/content/drive/MyDrive/neuralhydrology/exp/LSTM.yml"), gpu=-1)
# Out:
# 2022-07-28 11:33:00,964: Logging to /content/drive/MyDrive/neuralhydrology/runs/exp_run_LSTM_2807_113300/output.log initialized.
# 2022-07-28 11:33:00,967: ### Folder structure created at /content/drive/MyDrive/neuralhydrology/runs/exp_run_LSTM_2807_113300
# 2022-07-28 11:33:00,970: ### Run configurations for exp_run_LSTM
# 2022-07-28 11:33:00,972: experiment_name: exp_run_LSTM
# 2022-07-28 11:33:00,974: run_dir: /content/drive/MyDrive/neuralhydrology/runs/exp_run_LSTM_2807_113300
# 2022-07-28 11:33:00,977: train_basin_file: /content/drive/MyDrive/neuralhydrology/exp/train_basin_list.txt
# 2022-07-28 11:33:00,978: validation_basin_file: /content/drive/MyDrive/neuralhydrology/exp/test_val_basin_list.txt
# 2022-07-28 11:33:00,980: test_basin_file: /content/drive/MyDrive/neuralhydrology/exp/test_val_basin_list.txt
# 2022-07-28 11:33:00,982: train_start_date: 1999-10-01 00:00:00
# 2022-07-28 11:33:00,985: train_end_date: 2008-09-30 00:00:00
# ...
